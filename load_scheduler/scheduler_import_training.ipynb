# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix
from sqlalchemy import create_engine
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder
import category_encoders as ce
from sklearn.metrics import ConfusionMatrixDisplay
import xgboost as xgb
from sklearn.metrics import classification_report, accuracy_score
from datetime import datetime, timedelta
import joblib
import pickle

# %%
engine = create_engine('postgresql://read_only_dev:PxBcKG9D65iBzpz@hevo-cluster.cluster-ro-cwee21swjqfn.us-east-1.rds.amazonaws.com/hevo_prod')

# %%
available_loads_source_sql = '''
WITH date_ref AS (
    SELECT DATE %(reference_date)s AS ref_date
), available_loads AS (
    SELECT 
        ld.reference_number,
        CASE 
            WHEN (SUM(CASE WHEN date(dor.enroute AT TIME ZONE 'UTC' AT TIME ZONE %(time_zone)s) = ref_date AND dor.type = 'PULLCONTAINER' THEN 1 ELSE 0 END) > 0) AND 
                 (SUM(CASE WHEN date(dor.enroute AT TIME ZONE 'UTC' AT TIME ZONE %(time_zone)s) = ref_date AND dor.type = 'DELIVERLOAD' THEN 1 ELSE 0 END) > 0) AND 
                 (SUM(CASE WHEN date(dor.enroute AT TIME ZONE 'UTC' AT TIME ZONE %(time_zone)s) = ref_date AND dor.type = 'RETURNCONTAINER' THEN 1 ELSE 0 END) > 0) 
                THEN 'Pull-Deliver-Return'
            WHEN (SUM(CASE WHEN date(dor.enroute AT TIME ZONE 'UTC' AT TIME ZONE %(time_zone)s) = ref_date AND dor.type = 'PULLCONTAINER' THEN 1 ELSE 0 END) > 0) AND 
                 (SUM(CASE WHEN date(dor.enroute AT TIME ZONE 'UTC' AT TIME ZONE %(time_zone)s) = ref_date AND dor.type = 'DELIVERLOAD' THEN 1 ELSE 0 END) > 0) AND 
                 (SUM(CASE WHEN date(dor.enroute AT TIME ZONE 'UTC' AT TIME ZONE %(time_zone)s) = ref_date AND dor.type = 'RETURNCONTAINER' THEN 1 ELSE 0 END) = 0) 
                THEN 'Pull-Deliver'
            WHEN (SUM(CASE WHEN date(dor.enroute AT TIME ZONE 'UTC' AT TIME ZONE %(time_zone)s) = ref_date AND dor.type = 'PULLCONTAINER' THEN 1 ELSE 0 END) > 0) AND 
                 (SUM(CASE WHEN date(dor.enroute AT TIME ZONE 'UTC' AT TIME ZONE %(time_zone)s) = ref_date AND dor.type = 'DELIVERLOAD' THEN 1 ELSE 0 END) = 0) AND 
                 (SUM(CASE WHEN date(dor.enroute AT TIME ZONE 'UTC' AT TIME ZONE %(time_zone)s) = ref_date AND dor.type = 'RETURNCONTAINER' THEN 1 ELSE 0 END) = 0) 
                THEN 'Pre-Pull'
            ELSE 'Do Nothing'
        END AS Next_Move
    FROM date_ref, events dor 
    LEFT JOIN loads ld ON dor.loadid = ld._id
    WHERE ld.carrier IN %(carrier)s
        AND ld.type_of_load IN ('IMPORT')
        AND ld.availabledate IS NOT NULL
        AND ld.actual_pickup_date IS NOT NULL
        AND date(ld.actual_pickup_date AT TIME ZONE 'UTC' AT TIME ZONE %(time_zone)s) >= ref_date
        AND date(ld.availabledate AT TIME ZONE 'UTC' AT TIME ZONE %(time_zone)s) <= ref_date
    GROUP BY ld.reference_number
)
SELECT
    al.reference_number,
    al.Next_Move,
    ld.carrier,
    ld.distance,
    ld.callername AS "callerName",
    ld.shippername AS "shipperName",
    ld.consigneename AS "consigneeName",
    ld.hot,
    ld.type_of_load,
    ld.containersizename AS "containerSizeName",
    cg.totalamountwithtax AS "revenue",
    EXTRACT(day FROM (ld.lastfreeday - ref_date)) AS "lastFreeDay",
    EXTRACT(day FROM (ld.dischargeddate - ref_date)) AS "dischargedDate", 
    EXTRACT(day FROM (ld.availabledate - ref_date)) AS "availableDate",
    EXTRACT(dow FROM ref_date) AS "DOW"
FROM date_ref, loads ld
RIGHT JOIN available_loads al ON ld.reference_number = al.reference_number
LEFT JOIN chargegroups cg ON ld.reference_number = cg.load_reference_number
WHERE ld.carrier IN %(carrier)s
    AND ld.callername IS NOT NULL
    AND ld.shippername IS NOT NULL
    AND ld.consigneename IS NOT NULL
    AND al.reference_number IN (SELECT reference_number FROM available_loads)
    AND cg.isdefault = true;
'''

# %%
prepulled_loads_source_sql = '''
WITH date_ref AS (
    SELECT DATE %(reference_date)s AS ref_date
), prepulled_loads AS (
    SELECT 
        ld.reference_number,
        CASE 
            WHEN (SUM(CASE WHEN date(dor.enroute AT TIME ZONE 'UTC' AT TIME ZONE %(time_zone)s) = ref_date AND dor.type = 'DELIVERLOAD' THEN 1 ELSE 0 END) > 0) AND
                (SUM(CASE WHEN date(dor.enroute AT TIME ZONE 'UTC' AT TIME ZONE %(time_zone)s) = ref_date AND dor.type = 'HOOKCONTAINER' THEN 1 ELSE 0 END) > 0) AND
                (SUM(CASE WHEN date(dor.enroute AT TIME ZONE 'UTC' AT TIME ZONE %(time_zone)s) = ref_date AND dor.type = 'RETURNCONTAINER' THEN 1 ELSE 0 END) > 0) AND
                (MIN(CASE WHEN dor.type = 'HOOKCONTAINER' THEN dor.enroute ELSE NULL END) < 
                MIN(CASE WHEN dor.type = 'DELIVERLOAD' THEN dor.enroute ELSE NULL END)) 
                THEN 'Deliver-Return'
            WHEN (SUM(CASE WHEN date(dor.enroute AT TIME ZONE 'UTC' AT TIME ZONE %(time_zone)s) = ref_date AND dor.type = 'DELIVERLOAD' THEN 1 ELSE 0 END) > 0) AND 
                 (SUM(CASE WHEN date(dor.enroute AT TIME ZONE 'UTC' AT TIME ZONE %(time_zone)s) = ref_date AND dor.type = 'RETURNCONTAINER' THEN 1 ELSE 0 END) = 0) 
                THEN 'Deliver'
            ELSE 'Do Nothing' 
        END AS Next_Move 
    FROM date_ref, events dor 
    LEFT JOIN loads ld ON dor.loadid = ld._id
    WHERE ld.carrier IN %(carrier)s
        AND ld.type_of_load IN ('IMPORT')
        AND ld.actual_delivery_date IS NOT NULL
        AND ld.actual_pickup_date IS NOT NULL
        AND date(ld.actual_delivery_date AT TIME ZONE 'UTC' AT TIME ZONE %(time_zone)s) >= ref_date
        AND date(ld.actual_pickup_date AT TIME ZONE 'UTC' AT TIME ZONE %(time_zone)s) < ref_date
    GROUP BY ld.reference_number
)
SELECT  
    pl.reference_number,
    pl.Next_Move,
    ld.carrier,
    ld.distance,
    ld.callername AS "callerName", 
    ld.shippername AS "shipperName", 
    ld.consigneename AS "consigneeName",
    ld.type_of_load,
    ld.containersizename AS "containerSizeName",
    cg.totalamountwithtax AS "revenue",
    EXTRACT(day FROM (ld.lastfreeday - ref_date)) AS "lastFreeDay",
    EXTRACT(day FROM (ld.pickuptimes_0_pickupfromtime - ref_date)) AS "pickupFromTime", 
    EXTRACT(day FROM (ld.pickuptimes_0_pickuptotime - ref_date)) AS "pickupToTime",
    EXTRACT(day FROM (ld.dischargeddate - ref_date)) AS "dischargedDate",
    EXTRACT(day FROM (ld.availabledate - ref_date)) AS "availableDate",
    EXTRACT(dow FROM ref_date) AS "DOW"
FROM date_ref, loads ld 
RIGHT JOIN prepulled_loads pl ON ld.reference_number = pl.reference_number
LEFT JOIN chargegroups cg ON ld.reference_number = cg.load_reference_number
WHERE ld.carrier IN %(carrier)s
    AND ld.callername IS NOT NULL
    AND ld.shippername IS NOT NULL
    AND ld.consigneename IS NOT NULL
    AND pl.reference_number IN (SELECT reference_number FROM prepulled_loads)
    AND cg.isdefault = true;
'''

# %%
delivered_loads_source_sql = '''
WITH date_ref AS (
    SELECT DATE %(reference_date)s AS ref_date
), delivered_loads AS (
    SELECT 
        ld.reference_number,
        CASE 
            WHEN SUM(CASE 
                WHEN date(dor.enroute AT TIME ZONE 'UTC' AT TIME ZONE %(time_zone)s) = ref_date 
                AND dor.type = 'RETURNCONTAINER' THEN 1 
                ELSE 0 
            END) > 0 THEN 'Return'
            ELSE 'Do Nothing' 
        END AS Next_Move
    FROM date_ref, events dor 
    LEFT JOIN loads ld ON dor.loadid = ld._id
    WHERE ld.carrier IN %(carrier)s
        AND ld.type_of_load IN ('IMPORT')
        AND ld.actual_return_date IS NOT NULL
        AND ld.actual_delivery_date IS NOT NULL
        AND date(ld.actual_return_date AT TIME ZONE 'UTC' AT TIME ZONE %(time_zone)s) >= ref_date
        AND date(ld.actual_delivery_date AT TIME ZONE 'UTC' AT TIME ZONE %(time_zone)s) < ref_date
    GROUP BY ld.reference_number
)
SELECT  
    dl.reference_number,
    dl.Next_Move,
    ld.carrier,
    ld.distance,
    ld.callername AS "callerName", 
    ld.shippername AS "shipperName", 
    ld.consigneename AS "consigneeName",
    ld.type_of_load,
    ld.containersizename AS "containerSizeName",
    cg.totalamountwithtax AS "revenue",
    EXTRACT(day FROM (ld.freereturndate - ref_date)) AS "freeReturnDate",
    EXTRACT(day FROM (ld.emptyday - ref_date)) AS "emptyDay",
    EXTRACT(day FROM (ld.pickuptimes_0_pickupfromtime - ref_date)) AS "pickupFromTime", 
    EXTRACT(day FROM (ld.pickuptimes_0_pickuptotime - ref_date)) AS "pickupToTime", 
    EXTRACT(day FROM (ld.deliverytimes_0_deliveryfromtime - ref_date)) AS "deliveryFromTime", 
    EXTRACT(day FROM (ld.deliverytimes_0_deliverytotime - ref_date)) AS "deliveryToTime",  
    EXTRACT(day FROM (ld.dischargeddate - ref_date)) AS "dischargedDate",
    EXTRACT(day FROM (ld.availabledate - ref_date)) AS "availableDate",
    EXTRACT(dow FROM ref_date) AS "DOW" 
FROM date_ref, loads ld 
RIGHT JOIN delivered_loads dl ON ld.reference_number = dl.reference_number
LEFT JOIN chargegroups cg ON ld.reference_number = cg.load_reference_number
WHERE ld.carrier IN %(carrier)s
    AND ld.callername IS NOT NULL
    AND ld.shippername IS NOT NULL
    AND ld.consigneename IS NOT NULL
    AND dl.reference_number IN (SELECT reference_number FROM delivered_loads)
    AND cg.isdefault = true;
'''

# %%
def next_move_classifier(loads_type, carrier_names, target_dates):
    carrier_dict = {
        'RoadEx': ('641a10875b159a160742327e', 'PST'),
        'Best Drayage': ('6509badea6dea315ddddd273', 'EST'),
        'DHE': ('60747b8448cb687a0f377e82', 'EST'),
        'Loyalty': ('5a39472b4a819b31e9496084', 'EST'),
        'Quality_Container': ('653a6813f7eb901615236816', 'EST'),
        'bound': ('5ee790f864ca3551b0245d34', 'EST'),
        'uncommon': ('64fa0f62853f4a1621775bae', 'EST'),
        'seaport': ('6500ac3f5b4e7715cea4a2fe', 'EST'),
        'tripoint': ('63039f613d347315e2a02a2d', 'EST'),
        'alpha': ('6478bad770a34316adb76c24', 'EST'),
        'dile': ('623a1a0ae85bec6eacd5096d', 'EST')
    }

    carrier_info = [carrier_dict.get(carrier_name) for carrier_name in carrier_names]

    days_range = 90
    excluded_days = [(datetime(2024, 12, 21) + timedelta(days=i)).strftime('%Y-%m-%d') for i in range(16)]

    # Generate the list dynamically, excluding specified days
    target_date = target_dates[0]
    sql_params_train_list = []
    target_date = target_dates[0]
    for carrier_id, tz in carrier_info:
        for day in range(days_range + 16, 0, -1):
            ref_date = (datetime.strptime(target_date, '%Y-%m-%d') - timedelta(days=day)).strftime('%Y-%m-%d')
            if ref_date not in excluded_days:
                sql_params_train_list.append({
                    'carrier': tuple([carrier_id]),
                    'reference_date': ref_date,
                    'time_zone': tz
                })

    # Generate sql_params_test_list for each carrier_id/time_zone combination
    sql_params_test_list = []
    for carrier_id, tz in carrier_info:
        for day in target_dates:
            sql_params_test_list.append({
                'carrier': tuple([carrier_id]),
                'reference_date': datetime.strptime(day, '%Y-%m-%d'),
                'time_zone': tz
            })

    if loads_type == 'available':
        query = available_loads_source_sql
    elif loads_type == 'pre_pulled':
        query = prepulled_loads_source_sql
    elif loads_type == 'pending_return':
        query = delivered_loads_source_sql

    dfs = []
    for params in sql_params_train_list:
        df = pd.read_sql(query, engine, params=params)
        print("Retrieved "+str(len(df))+" data for "+params['reference_date'])
        dfs.append(df)

    # Combine all DataFrames into one using pd.concat() for the union
    df_train = pd.concat(dfs, ignore_index=True)

    dfs = []
    for params in sql_params_test_list:
        df = pd.read_sql(query, engine, params=params)
        print("Retrieved "+str(len(df))+" data for "+ str(params['reference_date']))
        dfs.append(df)

    df_test = pd.concat(dfs, ignore_index=True)

    label_encoder = LabelEncoder()
    label_encoder.fit(pd.concat([df_train['next_move'], df_test['next_move']]))

    df_train['next_move'] = label_encoder.transform(df_train['next_move'])
    df_test['next_move'] = label_encoder.transform(df_test['next_move'])

    # Separate features and target
    X_train = df_train.drop(['next_move', 'reference_number'], axis=1)  
    y_train = df_train['next_move']  

    X_test = df_test.drop(['next_move', 'reference_number'], axis=1)  
    y_test = df_test['next_move']  

    print("==============================")
    # Check class distribution in the training and test set
    class_distribution_train = y_train.value_counts()
    class_distribution_test = y_test.value_counts()

    print("Class distribution in training set:")
    print(class_distribution_train)

    print("\nClass distribution in test set:")
    print(class_distribution_test)

    print("==============================")
    # Check for missing values in training and test sets
    missing_train = X_train.isnull().sum()
    missing_test = X_test.isnull().sum()

    print("Missing values in training data:")
    print(missing_train[missing_train > 0])

    print("\nMissing values in test data:")
    print(missing_test[missing_test > 0])

    print("==============================")

    # Identify categorical columns
    categorical_columns = X_train.select_dtypes(include=['object']).columns

    encoder = ce.TargetEncoder(cols=categorical_columns)
    X_train[categorical_columns] = encoder.fit_transform(X_train[categorical_columns], df_train['next_move'])
    X_test[categorical_columns] = encoder.transform(X_test[categorical_columns])

    dtrain = xgb.DMatrix(X_train, label=y_train, enable_categorical=True)
    dtest = xgb.DMatrix(X_test, label=y_test, enable_categorical=True)

    # Set the parameters for XGBoost
    params = {
        'objective': 'multi:softprob',  # For multi-class probability outputs
        'eval_metric': 'mlogloss',      # Use multi-class log loss
        'eta': 0.1,                     # Learning rate
        'max_depth': 6,                 # Max depth of the trees
        'num_class': len(np.unique(y_train)),  # Number of unique classes
        'random_state': 42
    }

    param_grid = {
        'eta': [0.01, 0.1, 0.3],
        'max_depth': [4, 6, 8],
        'subsample': [0.8, 1.0],
        'colsample_bytree': [0.8, 1.0],
        'num_boost_round': [50, 100, 200]
    }

    best_params = None
    best_score = float('inf')

    for eta in param_grid['eta']:
        for max_depth in param_grid['max_depth']:
            for subsample in param_grid['subsample']:
                for colsample_bytree in param_grid['colsample_bytree']:
                    for num_boost_round in param_grid['num_boost_round']:
                        params['eta'] = eta
                        params['max_depth'] = max_depth
                        params['subsample'] = subsample
                        params['colsample_bytree'] = colsample_bytree

                        cv_results = xgb.cv(
                            params,
                            dtrain,
                            num_boost_round=num_boost_round,
                            nfold=5,
                            metrics='mlogloss',
                            early_stopping_rounds=10,
                            seed=42
                        )

                        mean_mlogloss = cv_results['test-mlogloss-mean'].min()
                        if mean_mlogloss < best_score:
                            best_score = mean_mlogloss
                            best_params = params.copy()
                            best_params['num_boost_round'] = num_boost_round

    print(f"Best parameters: {best_params}")
    print(f"Best mlogloss: {best_score}")

    # Update the parameters with the best found during tuning
    params.update(best_params)
    # Train the XGBoost model
    model = xgb.train(params, dtrain)

    # Add class labels to metadata
    class_labels = ','.join(label_encoder.classes_)
    model.set_attr(class_labels=class_labels)

    # Create a dynamic filename using the current timestamp
    filename = f"model_schedule_{loads_type}_IMPORT.pkl"
    
    # Save the model and encoder with the dynamic filename
    with open(filename, "wb") as f:
        raw_model = model.save_raw()
        pickle.dump((raw_model, encoder), f)

    # Make predictions (probabilities for each class)
    y_pred_prob = model.predict(dtest)

    y_pred = [np.argmax(probabilities) for probabilities in y_pred_prob]
    y_pred = label_encoder.inverse_transform(y_pred)
    y_test = label_encoder.inverse_transform(y_test)

    y_pred_series = pd.Series(y_pred, name='Predicted')
    X_input = df_test.drop(['next_move'], axis=1)  
    df_actions = pd.concat([y_pred_series, X_input], axis=1)
    df_dispatch = df_actions[df_actions['Predicted'] != 'Do Nothing']

    # Evaluate the model
    print('Classification Report for ' + loads_type)
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print("Classification Report:\n", classification_report(y_test, y_pred, zero_division=0))

    # Create a confusion matrix with unique labels
    cm = confusion_matrix(y_test, y_pred, labels=np.union1d(y_test, y_pred))
    cmd = ConfusionMatrixDisplay(cm, display_labels=np.union1d(y_test, y_pred))

    plt.figure(figsize=(10, 6))
    cmd.plot(cmap=plt.cm.Blues)
    plt.title('Confusion Matrix - Actual vs Predicted')
    plt.show()

    # Countplot for Actual vs Predicted
    comparison_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
    plt.figure(figsize=(12, 6))
    sns.countplot(x='Actual', data=comparison_df, color='blue', label='Actual', alpha=0.6)
    sns.countplot(x='Predicted', data=comparison_df, color='red', label='Predicted', alpha=0.4)
    plt.title('Actual vs Predicted Counts')
    plt.xlabel('Class')
    plt.ylabel('Frequency')
    plt.legend()
    plt.show()

    # Get the feature importance scores
    importance = model.get_score(importance_type='weight')  # Use 'gain' or 'cover' as needed
    importance_sorted = sorted(importance.items(), key=lambda x: x[1], reverse=True)

    for feature, score in importance_sorted:
        print(f'Feature: {feature}, Importance: {score}')

    xgb.plot_importance(model, importance_type='weight')
    plt.show()

    return df_dispatch

# %%
days = ['2025-05-19', '2025-05-20', '2025-05-21', '2025-05-22', '2025-05-23']

for set in ['pre_pulled', 'pending_return']:
    DispatchPlan = pd.DataFrame()
    Plan = next_move_classifier(set, ['tripoint', 'Loyalty', 'Quality_Container', 'RoadEx', 'dile', 'alpha'], days)
    DispatchPlan = pd.concat([DispatchPlan, Plan], ignore_index=True)

print('Recommended Dispatch Plan is Ready!')
# Out:
# Retrieved 54 data for 2025-02-02
# Retrieved 59 data for 2025-02-03
# Retrieved 49 data for 2025-02-04
# Retrieved 46 data for 2025-02-05
# Retrieved 34 data for 2025-02-06
# Retrieved 29 data for 2025-02-07
# Retrieved 35 data for 2025-02-08
# Retrieved 48 data for 2025-02-09
# Retrieved 57 data for 2025-02-10
# Retrieved 65 data for 2025-02-11
# Retrieved 62 data for 2025-02-12
# Retrieved 55 data for 2025-02-13
# Retrieved 52 data for 2025-02-14
# Retrieved 38 data for 2025-02-15
# Retrieved 53 data for 2025-02-16
# Retrieved 56 data for 2025-02-17
# Retrieved 72 data for 2025-02-18
# Retrieved 59 data for 2025-02-19
# Retrieved 43 data for 2025-02-20
# Retrieved 37 data for 2025-02-21
# Retrieved 34 data for 2025-02-22
# Retrieved 48 data for 2025-02-23
# Retrieved 65 data for 2025-02-24
# Retrieved 40 data for 2025-02-25
# Retrieved 34 data for 2025-02-26
# Retrieved 33 data for 2025-02-27
# Retrieved 34 data for 2025-02-28
# Retrieved 43 data for 2025-03-01
# Retrieved 62 data for 2025-03-02
# Retrieved 76 data for 2025-03-03
# Retrieved 50 data for 2025-03-04
# Retrieved 45 data for 2025-03-05
# Retrieved 39 data for 2025-03-06
# Retrieved 42 data for 2025-03-07
# Retrieved 40 data for 2025-03-08
# Retrieved 56 data for 2025-03-09
# Retrieved 73 data for 2025-03-10
# Retrieved 51 data for 2025-03-11
# Retrieved 43 data for 2025-03-12
# Retrieved 39 data for 2025-03-13
# Retrieved 36 data for 2025-03-14
# Retrieved 34 data for 2025-03-15
# Retrieved 39 data for 2025-03-16
# Retrieved 49 data for 2025-03-17
# Retrieved 52 data for 2025-03-18
# Retrieved 45 data for 2025-03-19
# Retrieved 42 data for 2025-03-20
# Retrieved 37 data for 2025-03-21
# Retrieved 44 data for 2025-03-22
# Retrieved 54 data for 2025-03-23
# Retrieved 72 data for 2025-03-24
# Retrieved 52 data for 2025-03-25
# Retrieved 53 data for 2025-03-26
# Retrieved 44 data for 2025-03-27
# Retrieved 38 data for 2025-03-28
# Retrieved 39 data for 2025-03-29
# Retrieved 74 data for 2025-03-30
# Retrieved 93 data for 2025-03-31
# Retrieved 91 data for 2025-04-01
# Retrieved 68 data for 2025-04-02
# Retrieved 48 data for 2025-04-03
# Retrieved 44 data for 2025-04-04
# Retrieved 43 data for 2025-04-05
# Retrieved 81 data for 2025-04-06
# Retrieved 94 data for 2025-04-07
# Retrieved 67 data for 2025-04-08
# Retrieved 57 data for 2025-04-09
# Retrieved 50 data for 2025-04-10
# Retrieved 53 data for 2025-04-11
# Retrieved 49 data for 2025-04-12
# Retrieved 69 data for 2025-04-13
# Retrieved 76 data for 2025-04-14
# Retrieved 59 data for 2025-04-15
# Retrieved 48 data for 2025-04-16
# Retrieved 44 data for 2025-04-17
# Retrieved 35 data for 2025-04-18
# Retrieved 39 data for 2025-04-19
# Retrieved 72 data for 2025-04-20
# Retrieved 99 data for 2025-04-21
# Retrieved 64 data for 2025-04-22
# Retrieved 40 data for 2025-04-23
# Retrieved 43 data for 2025-04-24
# Retrieved 29 data for 2025-04-25
# Retrieved 23 data for 2025-04-26
# Retrieved 48 data for 2025-04-27
# Retrieved 61 data for 2025-04-28
# Retrieved 53 data for 2025-04-29
# Retrieved 55 data for 2025-04-30
# Retrieved 48 data for 2025-05-01
# Retrieved 48 data for 2025-05-02
# Retrieved 44 data for 2025-05-03
# Retrieved 56 data for 2025-05-04
# Retrieved 66 data for 2025-05-05
# Retrieved 52 data for 2025-05-06
# Retrieved 45 data for 2025-05-07
# Retrieved 33 data for 2025-05-08
# Retrieved 34 data for 2025-05-09
# Retrieved 29 data for 2025-05-10
# Retrieved 76 data for 2025-05-11
# Retrieved 103 data for 2025-05-12
# Retrieved 88 data for 2025-05-13
# Retrieved 61 data for 2025-05-14
# Retrieved 51 data for 2025-05-15
# Retrieved 50 data for 2025-05-16
# Retrieved 48 data for 2025-05-17
# Retrieved 69 data for 2025-05-18
# Retrieved 55 data for 2025-02-02
# Retrieved 53 data for 2025-02-03
# Retrieved 58 data for 2025-02-04
# Retrieved 53 data for 2025-02-05
# Retrieved 63 data for 2025-02-06
# Retrieved 59 data for 2025-02-07
# Retrieved 40 data for 2025-02-08
# Retrieved 39 data for 2025-02-09
# Retrieved 36 data for 2025-02-10
# Retrieved 43 data for 2025-02-11
# Retrieved 42 data for 2025-02-12
# Retrieved 36 data for 2025-02-13
# Retrieved 56 data for 2025-02-14
# Retrieved 79 data for 2025-02-15
# Retrieved 79 data for 2025-02-16
# Retrieved 78 data for 2025-02-17
# Retrieved 44 data for 2025-02-18
# Retrieved 58 data for 2025-02-19
# Retrieved 60 data for 2025-02-20
# Retrieved 71 data for 2025-02-21
# Retrieved 66 data for 2025-02-22
# Retrieved 63 data for 2025-02-23
# Retrieved 63 data for 2025-02-24
# Retrieved 58 data for 2025-02-25
# Retrieved 84 data for 2025-02-26
# Retrieved 87 data for 2025-02-27
# Retrieved 66 data for 2025-02-28
# Retrieved 61 data for 2025-03-01
# Retrieved 61 data for 2025-03-02
# Retrieved 61 data for 2025-03-03
# Retrieved 72 data for 2025-03-04
# Retrieved 67 data for 2025-03-05
# Retrieved 81 data for 2025-03-06
# Retrieved 82 data for 2025-03-07
# Retrieved 58 data for 2025-03-08
# Retrieved 58 data for 2025-03-09
# Retrieved 57 data for 2025-03-10
# Retrieved 92 data for 2025-03-11
# Retrieved 89 data for 2025-03-12
# Retrieved 94 data for 2025-03-13
# Retrieved 86 data for 2025-03-14
# Retrieved 84 data for 2025-03-15
# Retrieved 84 data for 2025-03-16
# Retrieved 83 data for 2025-03-17
# Retrieved 39 data for 2025-03-18
# Retrieved 67 data for 2025-03-19
# Retrieved 89 data for 2025-03-20
# Retrieved 80 data for 2025-03-21
# Retrieved 60 data for 2025-03-22
# Retrieved 57 data for 2025-03-23
# Retrieved 57 data for 2025-03-24
# Retrieved 54 data for 2025-03-25
# Retrieved 64 data for 2025-03-26
# Retrieved 55 data for 2025-03-27
# Retrieved 46 data for 2025-03-28
# Retrieved 35 data for 2025-03-29
# Retrieved 33 data for 2025-03-30
# Retrieved 32 data for 2025-03-31
# Retrieved 39 data for 2025-04-01
# Retrieved 43 data for 2025-04-02
# Retrieved 48 data for 2025-04-03
# Retrieved 42 data for 2025-04-04
# Retrieved 36 data for 2025-04-05
# Retrieved 36 data for 2025-04-06
# Retrieved 36 data for 2025-04-07
# Retrieved 40 data for 2025-04-08
# Retrieved 35 data for 2025-04-09
# Retrieved 42 data for 2025-04-10
# Retrieved 50 data for 2025-04-11
# Retrieved 53 data for 2025-04-12
# Retrieved 52 data for 2025-04-13
# Retrieved 50 data for 2025-04-14
# Retrieved 64 data for 2025-04-15
# Retrieved 81 data for 2025-04-16
# Retrieved 89 data for 2025-04-17
# Retrieved 107 data for 2025-04-18
# Retrieved 80 data for 2025-04-19
# Retrieved 78 data for 2025-04-20
# Retrieved 78 data for 2025-04-21
# Retrieved 96 data for 2025-04-22
# Retrieved 77 data for 2025-04-23
# Retrieved 61 data for 2025-04-24
# Retrieved 68 data for 2025-04-25
# Retrieved 69 data for 2025-04-26
# Retrieved 66 data for 2025-04-27
# Retrieved 66 data for 2025-04-28
# Retrieved 76 data for 2025-04-29
# Retrieved 85 data for 2025-04-30
# Retrieved 77 data for 2025-05-01
# Retrieved 82 data for 2025-05-02
# Retrieved 64 data for 2025-05-03
# Retrieved 62 data for 2025-05-04
# Retrieved 62 data for 2025-05-05
# Retrieved 80 data for 2025-05-06
# Retrieved 88 data for 2025-05-07
# Retrieved 104 data for 2025-05-08
# Retrieved 72 data for 2025-05-09
# Retrieved 56 data for 2025-05-10
# Retrieved 56 data for 2025-05-11
# Retrieved 56 data for 2025-05-12
# Retrieved 70 data for 2025-05-13
# Retrieved 61 data for 2025-05-14
# Retrieved 62 data for 2025-05-15
# Retrieved 55 data for 2025-05-16
# Retrieved 44 data for 2025-05-17
# Retrieved 43 data for 2025-05-18
# Retrieved 108 data for 2025-02-02
# Retrieved 105 data for 2025-02-03
# Retrieved 117 data for 2025-02-04
# Retrieved 126 data for 2025-02-05
# Retrieved 112 data for 2025-02-06
# Retrieved 120 data for 2025-02-07
# Retrieved 130 data for 2025-02-08
# Retrieved 129 data for 2025-02-09
# Retrieved 128 data for 2025-02-10
# Retrieved 135 data for 2025-02-11
# Retrieved 134 data for 2025-02-12
# Retrieved 122 data for 2025-02-13
# Retrieved 100 data for 2025-02-14
# Retrieved 98 data for 2025-02-15
# Retrieved 96 data for 2025-02-16
# Retrieved 92 data for 2025-02-17
# Retrieved 86 data for 2025-02-18
# Retrieved 95 data for 2025-02-19
# Retrieved 84 data for 2025-02-20
# Retrieved 90 data for 2025-02-21
# Retrieved 98 data for 2025-02-22
# Retrieved 96 data for 2025-02-23
# Retrieved 90 data for 2025-02-24
# Retrieved 88 data for 2025-02-25
# Retrieved 71 data for 2025-02-26
# Retrieved 73 data for 2025-02-27
# Retrieved 67 data for 2025-02-28
# Retrieved 63 data for 2025-03-01
# Retrieved 62 data for 2025-03-02
# Retrieved 58 data for 2025-03-03
# Retrieved 57 data for 2025-03-04
# Retrieved 68 data for 2025-03-05
# Retrieved 57 data for 2025-03-06
# Retrieved 42 data for 2025-03-07
# Retrieved 143 data for 2025-03-08
# Retrieved 122 data for 2025-03-09
# Retrieved 120 data for 2025-03-10
# Retrieved 133 data for 2025-03-11
# Retrieved 153 data for 2025-03-12
# Retrieved 156 data for 2025-03-13
# Retrieved 166 data for 2025-03-14
# Retrieved 146 data for 2025-03-15
# Retrieved 145 data for 2025-03-16
# Retrieved 145 data for 2025-03-17
# Retrieved 101 data for 2025-03-18
# Retrieved 84 data for 2025-03-19
# Retrieved 96 data for 2025-03-20
# Retrieved 117 data for 2025-03-21
# Retrieved 99 data for 2025-03-22
# Retrieved 69 data for 2025-03-23
# Retrieved 67 data for 2025-03-24
# Retrieved 53 data for 2025-03-25
# Retrieved 74 data for 2025-03-26
# Retrieved 84 data for 2025-03-27
# Retrieved 75 data for 2025-03-28
# Retrieved 81 data for 2025-03-29
# Retrieved 75 data for 2025-03-30
# Retrieved 95 data for 2025-03-31
# Retrieved 121 data for 2025-04-01
# Retrieved 135 data for 2025-04-02
# Retrieved 117 data for 2025-04-03
# Retrieved 128 data for 2025-04-04
# Retrieved 139 data for 2025-04-05
# Retrieved 115 data for 2025-04-06
# Retrieved 110 data for 2025-04-07
# Retrieved 112 data for 2025-04-08
# Retrieved 119 data for 2025-04-09
# Retrieved 116 data for 2025-04-10
# Retrieved 110 data for 2025-04-11
# Retrieved 118 data for 2025-04-12
# Retrieved 121 data for 2025-04-13
# Retrieved 120 data for 2025-04-14
# Retrieved 148 data for 2025-04-15
# Retrieved 150 data for 2025-04-16
# Retrieved 150 data for 2025-04-17
# Retrieved 133 data for 2025-04-18
# Retrieved 109 data for 2025-04-19
# Retrieved 109 data for 2025-04-20
# Retrieved 109 data for 2025-04-21
# Retrieved 96 data for 2025-04-22
# Retrieved 90 data for 2025-04-23
# Retrieved 91 data for 2025-04-24
# Retrieved 96 data for 2025-04-25
# Retrieved 104 data for 2025-04-26
# Retrieved 93 data for 2025-04-27
# Retrieved 91 data for 2025-04-28
# Retrieved 97 data for 2025-04-29
# Retrieved 127 data for 2025-04-30
# Retrieved 139 data for 2025-05-01
# Retrieved 134 data for 2025-05-02
# Retrieved 129 data for 2025-05-03
# Retrieved 130 data for 2025-05-04
# Retrieved 130 data for 2025-05-05
# Retrieved 125 data for 2025-05-06
# Retrieved 119 data for 2025-05-07
# Retrieved 104 data for 2025-05-08
# Retrieved 97 data for 2025-05-09
# Retrieved 79 data for 2025-05-10
# Retrieved 77 data for 2025-05-11
# Retrieved 76 data for 2025-05-12
# Retrieved 73 data for 2025-05-13
# Retrieved 92 data for 2025-05-14
# Retrieved 120 data for 2025-05-15
# Retrieved 92 data for 2025-05-16
# Retrieved 72 data for 2025-05-17
# Retrieved 71 data for 2025-05-18
# Retrieved 107 data for 2025-02-02
# Retrieved 105 data for 2025-02-03
# Retrieved 133 data for 2025-02-04
# Retrieved 157 data for 2025-02-05
# Retrieved 141 data for 2025-02-06
# Retrieved 113 data for 2025-02-07
# Retrieved 131 data for 2025-02-08
# Retrieved 127 data for 2025-02-09
# Retrieved 120 data for 2025-02-10
# Retrieved 141 data for 2025-02-11
# Retrieved 145 data for 2025-02-12
# Retrieved 115 data for 2025-02-13
# Retrieved 101 data for 2025-02-14
# Retrieved 89 data for 2025-02-15
# Retrieved 86 data for 2025-02-16
# Retrieved 84 data for 2025-02-17
# Retrieved 118 data for 2025-02-18
# Retrieved 144 data for 2025-02-19
# Retrieved 143 data for 2025-02-20
# Retrieved 180 data for 2025-02-21
# Retrieved 113 data for 2025-02-22
# Retrieved 87 data for 2025-02-23
# Retrieved 87 data for 2025-02-24
# Retrieved 128 data for 2025-02-25
# Retrieved 184 data for 2025-02-26
# Retrieved 207 data for 2025-02-27
# Retrieved 213 data for 2025-02-28
# Retrieved 183 data for 2025-03-01
# Retrieved 166 data for 2025-03-02
# Retrieved 166 data for 2025-03-03
# Retrieved 220 data for 2025-03-04
# Retrieved 215 data for 2025-03-05
# Retrieved 228 data for 2025-03-06
# Retrieved 187 data for 2025-03-07
# Retrieved 146 data for 2025-03-08
# Retrieved 129 data for 2025-03-09
# Retrieved 127 data for 2025-03-10
# Retrieved 141 data for 2025-03-11
# Retrieved 171 data for 2025-03-12
# Retrieved 189 data for 2025-03-13
# Retrieved 193 data for 2025-03-14
# Retrieved 169 data for 2025-03-15
# Retrieved 166 data for 2025-03-16
# Retrieved 157 data for 2025-03-17
# Retrieved 160 data for 2025-03-18
# Retrieved 136 data for 2025-03-19
# Retrieved 118 data for 2025-03-20
# Retrieved 89 data for 2025-03-21
# Retrieved 59 data for 2025-03-22
# Retrieved 63 data for 2025-03-23
# Retrieved 65 data for 2025-03-24
# Retrieved 117 data for 2025-03-25
# Retrieved 151 data for 2025-03-26
# Retrieved 170 data for 2025-03-27
# Retrieved 171 data for 2025-03-28
# Retrieved 110 data for 2025-03-29
# Retrieved 98 data for 2025-03-30
# Retrieved 96 data for 2025-03-31
# Retrieved 104 data for 2025-04-01
# Retrieved 135 data for 2025-04-02
# Retrieved 128 data for 2025-04-03
# Retrieved 107 data for 2025-04-04
# Retrieved 94 data for 2025-04-05
# Retrieved 88 data for 2025-04-06
# Retrieved 95 data for 2025-04-07
# Retrieved 107 data for 2025-04-08
# Retrieved 114 data for 2025-04-09
# Retrieved 172 data for 2025-04-10
# Retrieved 179 data for 2025-04-11
# Retrieved 138 data for 2025-04-12
# Retrieved 136 data for 2025-04-13
# Retrieved 151 data for 2025-04-14
# Retrieved 149 data for 2025-04-15
# Retrieved 145 data for 2025-04-16
# Retrieved 118 data for 2025-04-17
# Retrieved 135 data for 2025-04-18
# Retrieved 109 data for 2025-04-19
# Retrieved 121 data for 2025-04-20
# Retrieved 121 data for 2025-04-21
# Retrieved 136 data for 2025-04-22
# Retrieved 159 data for 2025-04-23
# Retrieved 190 data for 2025-04-24
# Retrieved 226 data for 2025-04-25
# Retrieved 242 data for 2025-04-26
# Retrieved 242 data for 2025-04-27
# Retrieved 256 data for 2025-04-28
# Retrieved 274 data for 2025-04-29
# Retrieved 294 data for 2025-04-30
# Retrieved 268 data for 2025-05-01
# Retrieved 214 data for 2025-05-02
# Retrieved 207 data for 2025-05-03
# Retrieved 232 data for 2025-05-04
# Retrieved 248 data for 2025-05-05
# Retrieved 211 data for 2025-05-06
# Retrieved 223 data for 2025-05-07
# Retrieved 192 data for 2025-05-08
# Retrieved 194 data for 2025-05-09
# Retrieved 170 data for 2025-05-10
# Retrieved 159 data for 2025-05-11
# Retrieved 148 data for 2025-05-12
# Retrieved 154 data for 2025-05-13
# Retrieved 134 data for 2025-05-14
# Retrieved 117 data for 2025-05-15
# Retrieved 92 data for 2025-05-16
# Retrieved 70 data for 2025-05-17
# Retrieved 79 data for 2025-05-18
# Retrieved 0 data for 2025-02-02
# Retrieved 0 data for 2025-02-03
# Retrieved 0 data for 2025-02-04
# Retrieved 0 data for 2025-02-05
# Retrieved 0 data for 2025-02-06
# Retrieved 0 data for 2025-02-07
# Retrieved 2 data for 2025-02-08
# Retrieved 0 data for 2025-02-09
# Retrieved 0 data for 2025-02-10
# Retrieved 0 data for 2025-02-11
# Retrieved 0 data for 2025-02-12
# Retrieved 0 data for 2025-02-13
# Retrieved 1 data for 2025-02-14
# Retrieved 0 data for 2025-02-15
# Retrieved 0 data for 2025-02-16
# Retrieved 0 data for 2025-02-17
# Retrieved 1 data for 2025-02-18
# Retrieved 1 data for 2025-02-19
# Retrieved 4 data for 2025-02-20
# Retrieved 5 data for 2025-02-21
# Retrieved 3 data for 2025-02-22
# Retrieved 2 data for 2025-02-23
# Retrieved 2 data for 2025-02-24
# Retrieved 1 data for 2025-02-25
# Retrieved 2 data for 2025-02-26
# Retrieved 3 data for 2025-02-27
# Retrieved 3 data for 2025-02-28
# Retrieved 0 data for 2025-03-01
# Retrieved 0 data for 2025-03-02
# Retrieved 0 data for 2025-03-03
# Retrieved 2 data for 2025-03-04
# Retrieved 0 data for 2025-03-05
# Retrieved 0 data for 2025-03-06
# Retrieved 1 data for 2025-03-07
# Retrieved 1 data for 2025-03-08
# Retrieved 1 data for 2025-03-09
# Retrieved 1 data for 2025-03-10
# Retrieved 1 data for 2025-03-11
# Retrieved 9 data for 2025-03-12
# Retrieved 11 data for 2025-03-13
# Retrieved 15 data for 2025-03-14
# Retrieved 10 data for 2025-03-15
# Retrieved 10 data for 2025-03-16
# Retrieved 10 data for 2025-03-17
# Retrieved 11 data for 2025-03-18
# Retrieved 8 data for 2025-03-19
# Retrieved 9 data for 2025-03-20
# Retrieved 11 data for 2025-03-21
# Retrieved 15 data for 2025-03-22
# Retrieved 15 data for 2025-03-23
# Retrieved 15 data for 2025-03-24
# Retrieved 19 data for 2025-03-25
# Retrieved 21 data for 2025-03-26
# Retrieved 18 data for 2025-03-27
# Retrieved 14 data for 2025-03-28
# Retrieved 15 data for 2025-03-29
# Retrieved 15 data for 2025-03-30
# Retrieved 15 data for 2025-03-31
# Retrieved 14 data for 2025-04-01
# Retrieved 14 data for 2025-04-02
# Retrieved 9 data for 2025-04-03
# Retrieved 5 data for 2025-04-04
# Retrieved 0 data for 2025-04-05
# Retrieved 0 data for 2025-04-06
# Retrieved 0 data for 2025-04-07
# Retrieved 2 data for 2025-04-08
# Retrieved 2 data for 2025-04-09
# Retrieved 0 data for 2025-04-10
# Retrieved 2 data for 2025-04-11
# Retrieved 1 data for 2025-04-12
# Retrieved 1 data for 2025-04-13
# Retrieved 1 data for 2025-04-14
# Retrieved 4 data for 2025-04-15
# Retrieved 5 data for 2025-04-16
# Retrieved 4 data for 2025-04-17
# Retrieved 3 data for 2025-04-18
# Retrieved 0 data for 2025-04-19
# Retrieved 1 data for 2025-04-20
# Retrieved 2 data for 2025-04-21
# Retrieved 3 data for 2025-04-22
# Retrieved 3 data for 2025-04-23
# Retrieved 1 data for 2025-04-24
# Retrieved 3 data for 2025-04-25
# Retrieved 4 data for 2025-04-26
# Retrieved 4 data for 2025-04-27
# Retrieved 4 data for 2025-04-28
# Retrieved 4 data for 2025-04-29
# Retrieved 4 data for 2025-04-30
# Retrieved 3 data for 2025-05-01
# Retrieved 4 data for 2025-05-02
# Retrieved 0 data for 2025-05-03
# Retrieved 0 data for 2025-05-04
# Retrieved 0 data for 2025-05-05
# Retrieved 2 data for 2025-05-06
# Retrieved 2 data for 2025-05-07
# Retrieved 8 data for 2025-05-08
# Retrieved 6 data for 2025-05-09
# Retrieved 0 data for 2025-05-10
# Retrieved 1 data for 2025-05-11
# Retrieved 0 data for 2025-05-12
# Retrieved 4 data for 2025-05-13
# Retrieved 5 data for 2025-05-14
# Retrieved 5 data for 2025-05-15
# Retrieved 3 data for 2025-05-16
# Retrieved 1 data for 2025-05-17
# Retrieved 0 data for 2025-05-18
# Retrieved 47 data for 2025-02-02
# Retrieved 47 data for 2025-02-03
# Retrieved 24 data for 2025-02-04
# Retrieved 17 data for 2025-02-05
# Retrieved 16 data for 2025-02-06
# Retrieved 54 data for 2025-02-07
# Retrieved 30 data for 2025-02-08
# Retrieved 30 data for 2025-02-09
# Retrieved 30 data for 2025-02-10
# Retrieved 19 data for 2025-02-11
# Retrieved 22 data for 2025-02-12
# Retrieved 36 data for 2025-02-13
# Retrieved 46 data for 2025-02-14
# Retrieved 21 data for 2025-02-15
# Retrieved 20 data for 2025-02-16
# Retrieved 20 data for 2025-02-17
# Retrieved 9 data for 2025-02-18
# Retrieved 17 data for 2025-02-19
# Retrieved 14 data for 2025-02-20
# Retrieved 12 data for 2025-02-21
# Retrieved 3 data for 2025-02-22
# Retrieved 3 data for 2025-02-23
# Retrieved 3 data for 2025-02-24
# Retrieved 15 data for 2025-02-25
# Retrieved 18 data for 2025-02-26
# Retrieved 15 data for 2025-02-27
# Retrieved 31 data for 2025-02-28
# Retrieved 16 data for 2025-03-01
# Retrieved 14 data for 2025-03-02
# Retrieved 14 data for 2025-03-03
# Retrieved 20 data for 2025-03-04
# Retrieved 17 data for 2025-03-05
# Retrieved 21 data for 2025-03-06
# Retrieved 29 data for 2025-03-07
# Retrieved 13 data for 2025-03-08
# Retrieved 13 data for 2025-03-09
# Retrieved 13 data for 2025-03-10
# Retrieved 21 data for 2025-03-11
# Retrieved 15 data for 2025-03-12
# Retrieved 10 data for 2025-03-13
# Retrieved 17 data for 2025-03-14
# Retrieved 8 data for 2025-03-15
# Retrieved 8 data for 2025-03-16
# Retrieved 8 data for 2025-03-17
# Retrieved 2 data for 2025-03-18
# Retrieved 14 data for 2025-03-19
# Retrieved 8 data for 2025-03-20
# Retrieved 10 data for 2025-03-21
# Retrieved 11 data for 2025-03-22
# Retrieved 11 data for 2025-03-23
# Retrieved 10 data for 2025-03-24
# Retrieved 17 data for 2025-03-25
# Retrieved 15 data for 2025-03-26
# Retrieved 17 data for 2025-03-27
# Retrieved 14 data for 2025-03-28
# Retrieved 5 data for 2025-03-29
# Retrieved 5 data for 2025-03-30
# Retrieved 5 data for 2025-03-31
# Retrieved 13 data for 2025-04-01
# Retrieved 19 data for 2025-04-02
# Retrieved 15 data for 2025-04-03
# Retrieved 25 data for 2025-04-04
# Retrieved 25 data for 2025-04-05
# Retrieved 25 data for 2025-04-06
# Retrieved 25 data for 2025-04-07
# Retrieved 14 data for 2025-04-08
# Retrieved 19 data for 2025-04-09
# Retrieved 19 data for 2025-04-10
# Retrieved 24 data for 2025-04-11
# Retrieved 8 data for 2025-04-12
# Retrieved 8 data for 2025-04-13
# Retrieved 9 data for 2025-04-14
# Retrieved 21 data for 2025-04-15
# Retrieved 20 data for 2025-04-16
# Retrieved 22 data for 2025-04-17
# Retrieved 25 data for 2025-04-18
# Retrieved 3 data for 2025-04-19
# Retrieved 3 data for 2025-04-20
# Retrieved 3 data for 2025-04-21
# Retrieved 24 data for 2025-04-22
# Retrieved 28 data for 2025-04-23
# Retrieved 29 data for 2025-04-24
# Retrieved 37 data for 2025-04-25
# Retrieved 28 data for 2025-04-26
# Retrieved 25 data for 2025-04-27
# Retrieved 25 data for 2025-04-28
# Retrieved 21 data for 2025-04-29
# Retrieved 25 data for 2025-04-30
# Retrieved 19 data for 2025-05-01
# Retrieved 17 data for 2025-05-02
# Retrieved 7 data for 2025-05-03
# Retrieved 7 data for 2025-05-04
# Retrieved 7 data for 2025-05-05
# Retrieved 16 data for 2025-05-06
# Retrieved 22 data for 2025-05-07
# Retrieved 21 data for 2025-05-08
# Retrieved 34 data for 2025-05-09
# Retrieved 21 data for 2025-05-10
# Retrieved 19 data for 2025-05-11
# Retrieved 19 data for 2025-05-12
# Retrieved 22 data for 2025-05-13
# Retrieved 29 data for 2025-05-14
# Retrieved 29 data for 2025-05-15
# Retrieved 43 data for 2025-05-16
# Retrieved 20 data for 2025-05-17
# Retrieved 20 data for 2025-05-18
# C:\Users\David\AppData\Local\Temp\ipykernel_24188\120158157.py:59: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_train = pd.concat(dfs, ignore_index=True)
# Retrieved 74 data for 2025-05-19 00:00:00
# Retrieved 83 data for 2025-05-20 00:00:00
# Retrieved 72 data for 2025-05-21 00:00:00
# Retrieved 63 data for 2025-05-22 00:00:00
# Retrieved 44 data for 2025-05-23 00:00:00
# Retrieved 43 data for 2025-05-19 00:00:00
# Retrieved 50 data for 2025-05-20 00:00:00
# Retrieved 52 data for 2025-05-21 00:00:00
# Retrieved 52 data for 2025-05-22 00:00:00
# Retrieved 49 data for 2025-05-23 00:00:00
# Retrieved 69 data for 2025-05-19 00:00:00
# Retrieved 66 data for 2025-05-20 00:00:00
# Retrieved 55 data for 2025-05-21 00:00:00
# Retrieved 42 data for 2025-05-22 00:00:00
# Retrieved 30 data for 2025-05-23 00:00:00
# Retrieved 76 data for 2025-05-19 00:00:00
# Retrieved 72 data for 2025-05-20 00:00:00
# Retrieved 125 data for 2025-05-21 00:00:00
# Retrieved 107 data for 2025-05-22 00:00:00
# Retrieved 121 data for 2025-05-23 00:00:00
# Retrieved 0 data for 2025-05-19 00:00:00
# Retrieved 3 data for 2025-05-20 00:00:00
# Retrieved 3 data for 2025-05-21 00:00:00
# Retrieved 0 data for 2025-05-22 00:00:00
# Retrieved 3 data for 2025-05-23 00:00:00
# Retrieved 20 data for 2025-05-19 00:00:00
# Retrieved 18 data for 2025-05-20 00:00:00
# Retrieved 23 data for 2025-05-21 00:00:00
# Retrieved 24 data for 2025-05-22 00:00:00
# Retrieved 17 data for 2025-05-23 00:00:00
# ==============================
# Class distribution in training set:
# next_move
# 2    30139
# 0     7532
# 1     3930
# Name: count, dtype: int64
#
# Class distribution in test set:
# next_move
# 2    769
# 0    438
# 1    249
# Name: count, dtype: int64
# ==============================
# Missing values in training data:
# containerSizeName      78
# lastFreeDay          3140
# pickupFromTime       8804
# pickupToTime         8805
# dischargedDate       9519
# availableDate        4632
# dtype: int64
#
# Missing values in test data:
# containerSizeName      2
# lastFreeDay          116
# pickupFromTime       401
# pickupToTime         401
# dischargedDate       462
# availableDate        180
# dtype: int64
# ==============================
# C:\Users\David\AppData\Local\Temp\ipykernel_24188\120158157.py:67: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_test = pd.concat(dfs, ignore_index=True)
# Best parameters: {'objective': 'multi:softprob', 'eval_metric': 'mlogloss', 'eta': 0.3, 'max_depth': 8, 'num_class': 3, 'random_state': 42, 'subsample': 1.0, 'colsample_bytree': 0.8, 'num_boost_round': 200}
# Best mlogloss: 0.38635634204817954
# Classification Report for pre_pulled
# Accuracy: 0.6675824175824175
# Classification Report:
#                  precision    recall  f1-score   support
#
#        Deliver       0.61      0.35      0.44       438
# Deliver-Return       0.70      0.56      0.62       249
#     Do Nothing       0.68      0.88      0.77       769
#
#       accuracy                           0.67      1456
#      macro avg       0.66      0.60      0.61      1456
#   weighted avg       0.66      0.67      0.64      1456
# c:\ProgramData\anaconda3\envs\aws\Lib\site-packages\xgboost\core.py:158: UserWarning: [11:30:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "num_boost_round" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Feature: revenue, Importance: 751.0
# Feature: distance, Importance: 652.0
# Feature: dischargedDate, Importance: 498.0
# Feature: pickupFromTime, Importance: 423.0
# Feature: consigneeName, Importance: 399.0
# Feature: lastFreeDay, Importance: 380.0
# Feature: callerName, Importance: 289.0
# Feature: shipperName, Importance: 289.0
# Feature: availableDate, Importance: 282.0
# Feature: DOW, Importance: 259.0
# Feature: carrier, Importance: 116.0
# Feature: pickupToTime, Importance: 68.0
# Feature: containerSizeName, Importance: 40.0
# Retrieved 17 data for 2025-02-02
# Retrieved 19 data for 2025-02-03
# Retrieved 27 data for 2025-02-04
# Retrieved 22 data for 2025-02-05
# Retrieved 10 data for 2025-02-06
# Retrieved 12 data for 2025-02-07
# Retrieved 13 data for 2025-02-08
# Retrieved 15 data for 2025-02-09
# Retrieved 15 data for 2025-02-10
# Retrieved 19 data for 2025-02-11
# Retrieved 22 data for 2025-02-12
# Retrieved 20 data for 2025-02-13
# Retrieved 18 data for 2025-02-14
# Retrieved 12 data for 2025-02-15
# Retrieved 15 data for 2025-02-16
# Retrieved 15 data for 2025-02-17
# Retrieved 17 data for 2025-02-18
# Retrieved 31 data for 2025-02-19
# Retrieved 35 data for 2025-02-20
# Retrieved 29 data for 2025-02-21
# Retrieved 26 data for 2025-02-22
# Retrieved 25 data for 2025-02-23
# Retrieved 25 data for 2025-02-24
# Retrieved 20 data for 2025-02-25
# Retrieved 27 data for 2025-02-26
# Retrieved 28 data for 2025-02-27
# Retrieved 30 data for 2025-02-28
# Retrieved 39 data for 2025-03-01
# Retrieved 43 data for 2025-03-02
# Retrieved 43 data for 2025-03-03
# Retrieved 40 data for 2025-03-04
# Retrieved 26 data for 2025-03-05
# Retrieved 24 data for 2025-03-06
# Retrieved 18 data for 2025-03-07
# Retrieved 21 data for 2025-03-08
# Retrieved 26 data for 2025-03-09
# Retrieved 27 data for 2025-03-10
# Retrieved 38 data for 2025-03-11
# Retrieved 47 data for 2025-03-12
# Retrieved 45 data for 2025-03-13
# Retrieved 31 data for 2025-03-14
# Retrieved 25 data for 2025-03-15
# Retrieved 27 data for 2025-03-16
# Retrieved 28 data for 2025-03-17
# Retrieved 29 data for 2025-03-18
# Retrieved 29 data for 2025-03-19
# Retrieved 26 data for 2025-03-20
# Retrieved 19 data for 2025-03-21
# Retrieved 37 data for 2025-03-22
# Retrieved 36 data for 2025-03-23
# Retrieved 37 data for 2025-03-24
# Retrieved 40 data for 2025-03-25
# Retrieved 42 data for 2025-03-26
# Retrieved 43 data for 2025-03-27
# Retrieved 35 data for 2025-03-28
# Retrieved 30 data for 2025-03-29
# Retrieved 31 data for 2025-03-30
# Retrieved 29 data for 2025-03-31
# Retrieved 32 data for 2025-04-01
# Retrieved 32 data for 2025-04-02
# Retrieved 42 data for 2025-04-03
# Retrieved 26 data for 2025-04-04
# Retrieved 25 data for 2025-04-05
# Retrieved 29 data for 2025-04-06
# Retrieved 28 data for 2025-04-07
# Retrieved 38 data for 2025-04-08
# Retrieved 43 data for 2025-04-09
# Retrieved 32 data for 2025-04-10
# Retrieved 29 data for 2025-04-11
# Retrieved 19 data for 2025-04-12
# Retrieved 20 data for 2025-04-13
# Retrieved 20 data for 2025-04-14
# Retrieved 26 data for 2025-04-15
# Retrieved 25 data for 2025-04-16
# Retrieved 23 data for 2025-04-17
# Retrieved 18 data for 2025-04-18
# Retrieved 16 data for 2025-04-19
# Retrieved 18 data for 2025-04-20
# Retrieved 21 data for 2025-04-21
# Retrieved 34 data for 2025-04-22
# Retrieved 35 data for 2025-04-23
# Retrieved 30 data for 2025-04-24
# Retrieved 21 data for 2025-04-25
# Retrieved 11 data for 2025-04-26
# Retrieved 15 data for 2025-04-27
# Retrieved 17 data for 2025-04-28
# Retrieved 20 data for 2025-04-29
# Retrieved 23 data for 2025-04-30
# Retrieved 22 data for 2025-05-01
# Retrieved 33 data for 2025-05-02
# Retrieved 37 data for 2025-05-03
# Retrieved 38 data for 2025-05-04
# Retrieved 39 data for 2025-05-05
# Retrieved 28 data for 2025-05-06
# Retrieved 21 data for 2025-05-07
# Retrieved 19 data for 2025-05-08
# Retrieved 18 data for 2025-05-09
# Retrieved 14 data for 2025-05-10
# Retrieved 15 data for 2025-05-11
# Retrieved 15 data for 2025-05-12
# Retrieved 27 data for 2025-05-13
# Retrieved 40 data for 2025-05-14
# Retrieved 39 data for 2025-05-15
# Retrieved 38 data for 2025-05-16
# Retrieved 14 data for 2025-05-17
# Retrieved 14 data for 2025-05-18
# Retrieved 73 data for 2025-02-02
# Retrieved 75 data for 2025-02-03
# Retrieved 75 data for 2025-02-04
# Retrieved 84 data for 2025-02-05
# Retrieved 67 data for 2025-02-06
# Retrieved 72 data for 2025-02-07
# Retrieved 54 data for 2025-02-08
# Retrieved 55 data for 2025-02-09
# Retrieved 58 data for 2025-02-10
# Retrieved 65 data for 2025-02-11
# Retrieved 68 data for 2025-02-12
# Retrieved 76 data for 2025-02-13
# Retrieved 87 data for 2025-02-14
# Retrieved 79 data for 2025-02-15
# Retrieved 79 data for 2025-02-16
# Retrieved 80 data for 2025-02-17
# Retrieved 119 data for 2025-02-18
# Retrieved 104 data for 2025-02-19
# Retrieved 107 data for 2025-02-20
# Retrieved 102 data for 2025-02-21
# Retrieved 99 data for 2025-02-22
# Retrieved 102 data for 2025-02-23
# Retrieved 102 data for 2025-02-24
# Retrieved 107 data for 2025-02-25
# Retrieved 86 data for 2025-02-26
# Retrieved 75 data for 2025-02-27
# Retrieved 59 data for 2025-02-28
# Retrieved 60 data for 2025-03-01
# Retrieved 60 data for 2025-03-02
# Retrieved 59 data for 2025-03-03
# Retrieved 52 data for 2025-03-04
# Retrieved 58 data for 2025-03-05
# Retrieved 44 data for 2025-03-06
# Retrieved 35 data for 2025-03-07
# Retrieved 37 data for 2025-03-08
# Retrieved 37 data for 2025-03-09
# Retrieved 38 data for 2025-03-10
# Retrieved 33 data for 2025-03-11
# Retrieved 33 data for 2025-03-12
# Retrieved 41 data for 2025-03-13
# Retrieved 38 data for 2025-03-14
# Retrieved 33 data for 2025-03-15
# Retrieved 33 data for 2025-03-16
# Retrieved 34 data for 2025-03-17
# Retrieved 73 data for 2025-03-18
# Retrieved 59 data for 2025-03-19
# Retrieved 51 data for 2025-03-20
# Retrieved 26 data for 2025-03-21
# Retrieved 26 data for 2025-03-22
# Retrieved 29 data for 2025-03-23
# Retrieved 29 data for 2025-03-24
# Retrieved 31 data for 2025-03-25
# Retrieved 31 data for 2025-03-26
# Retrieved 27 data for 2025-03-27
# Retrieved 22 data for 2025-03-28
# Retrieved 29 data for 2025-03-29
# Retrieved 29 data for 2025-03-30
# Retrieved 30 data for 2025-03-31
# Retrieved 26 data for 2025-04-01
# Retrieved 21 data for 2025-04-02
# Retrieved 23 data for 2025-04-03
# Retrieved 29 data for 2025-04-04
# Retrieved 29 data for 2025-04-05
# Retrieved 29 data for 2025-04-06
# Retrieved 28 data for 2025-04-07
# Retrieved 24 data for 2025-04-08
# Retrieved 27 data for 2025-04-09
# Retrieved 32 data for 2025-04-10
# Retrieved 34 data for 2025-04-11
# Retrieved 39 data for 2025-04-12
# Retrieved 40 data for 2025-04-13
# Retrieved 42 data for 2025-04-14
# Retrieved 42 data for 2025-04-15
# Retrieved 22 data for 2025-04-16
# Retrieved 26 data for 2025-04-17
# Retrieved 20 data for 2025-04-18
# Retrieved 45 data for 2025-04-19
# Retrieved 47 data for 2025-04-20
# Retrieved 47 data for 2025-04-21
# Retrieved 39 data for 2025-04-22
# Retrieved 57 data for 2025-04-23
# Retrieved 67 data for 2025-04-24
# Retrieved 55 data for 2025-04-25
# Retrieved 38 data for 2025-04-26
# Retrieved 41 data for 2025-04-27
# Retrieved 41 data for 2025-04-28
# Retrieved 31 data for 2025-04-29
# Retrieved 17 data for 2025-04-30
# Retrieved 33 data for 2025-05-01
# Retrieved 21 data for 2025-05-02
# Retrieved 29 data for 2025-05-03
# Retrieved 31 data for 2025-05-04
# Retrieved 30 data for 2025-05-05
# Retrieved 20 data for 2025-05-06
# Retrieved 21 data for 2025-05-07
# Retrieved 23 data for 2025-05-08
# Retrieved 35 data for 2025-05-09
# Retrieved 47 data for 2025-05-10
# Retrieved 47 data for 2025-05-11
# Retrieved 47 data for 2025-05-12
# Retrieved 19 data for 2025-05-13
# Retrieved 19 data for 2025-05-14
# Retrieved 12 data for 2025-05-15
# Retrieved 15 data for 2025-05-16
# Retrieved 15 data for 2025-05-17
# Retrieved 16 data for 2025-05-18
# Retrieved 280 data for 2025-02-02
# Retrieved 280 data for 2025-02-03
# Retrieved 265 data for 2025-02-04
# Retrieved 287 data for 2025-02-05
# Retrieved 287 data for 2025-02-06
# Retrieved 276 data for 2025-02-07
# Retrieved 264 data for 2025-02-08
# Retrieved 254 data for 2025-02-09
# Retrieved 252 data for 2025-02-10
# Retrieved 251 data for 2025-02-11
# Retrieved 276 data for 2025-02-12
# Retrieved 242 data for 2025-02-13
# Retrieved 176 data for 2025-02-14
# Retrieved 186 data for 2025-02-15
# Retrieved 180 data for 2025-02-16
# Retrieved 181 data for 2025-02-17
# Retrieved 168 data for 2025-02-18
# Retrieved 191 data for 2025-02-19
# Retrieved 225 data for 2025-02-20
# Retrieved 252 data for 2025-02-21
# Retrieved 249 data for 2025-02-22
# Retrieved 248 data for 2025-02-23
# Retrieved 249 data for 2025-02-24
# Retrieved 223 data for 2025-02-25
# Retrieved 222 data for 2025-02-26
# Retrieved 195 data for 2025-02-27
# Retrieved 187 data for 2025-02-28
# Retrieved 186 data for 2025-03-01
# Retrieved 190 data for 2025-03-02
# Retrieved 190 data for 2025-03-03
# Retrieved 228 data for 2025-03-04
# Retrieved 266 data for 2025-03-05
# Retrieved 281 data for 2025-03-06
# Retrieved 293 data for 2025-03-07
# Retrieved 240 data for 2025-03-08
# Retrieved 242 data for 2025-03-09
# Retrieved 241 data for 2025-03-10
# Retrieved 202 data for 2025-03-11
# Retrieved 225 data for 2025-03-12
# Retrieved 240 data for 2025-03-13
# Retrieved 232 data for 2025-03-14
# Retrieved 201 data for 2025-03-15
# Retrieved 201 data for 2025-03-16
# Retrieved 201 data for 2025-03-17
# Retrieved 259 data for 2025-03-18
# Retrieved 272 data for 2025-03-19
# Retrieved 206 data for 2025-03-20
# Retrieved 175 data for 2025-03-21
# Retrieved 147 data for 2025-03-22
# Retrieved 152 data for 2025-03-23
# Retrieved 152 data for 2025-03-24
# Retrieved 135 data for 2025-03-25
# Retrieved 155 data for 2025-03-26
# Retrieved 184 data for 2025-03-27
# Retrieved 222 data for 2025-03-28
# Retrieved 215 data for 2025-03-29
# Retrieved 216 data for 2025-03-30
# Retrieved 217 data for 2025-03-31
# Retrieved 189 data for 2025-04-01
# Retrieved 206 data for 2025-04-02
# Retrieved 241 data for 2025-04-03
# Retrieved 223 data for 2025-04-04
# Retrieved 205 data for 2025-04-05
# Retrieved 210 data for 2025-04-06
# Retrieved 211 data for 2025-04-07
# Retrieved 179 data for 2025-04-08
# Retrieved 176 data for 2025-04-09
# Retrieved 189 data for 2025-04-10
# Retrieved 231 data for 2025-04-11
# Retrieved 240 data for 2025-04-12
# Retrieved 239 data for 2025-04-13
# Retrieved 239 data for 2025-04-14
# Retrieved 227 data for 2025-04-15
# Retrieved 251 data for 2025-04-16
# Retrieved 242 data for 2025-04-17
# Retrieved 207 data for 2025-04-18
# Retrieved 208 data for 2025-04-19
# Retrieved 207 data for 2025-04-20
# Retrieved 208 data for 2025-04-21
# Retrieved 175 data for 2025-04-22
# Retrieved 191 data for 2025-04-23
# Retrieved 188 data for 2025-04-24
# Retrieved 188 data for 2025-04-25
# Retrieved 167 data for 2025-04-26
# Retrieved 165 data for 2025-04-27
# Retrieved 165 data for 2025-04-28
# Retrieved 167 data for 2025-04-29
# Retrieved 193 data for 2025-04-30
# Retrieved 186 data for 2025-05-01
# Retrieved 213 data for 2025-05-02
# Retrieved 199 data for 2025-05-03
# Retrieved 198 data for 2025-05-04
# Retrieved 197 data for 2025-05-05
# Retrieved 184 data for 2025-05-06
# Retrieved 147 data for 2025-05-07
# Retrieved 161 data for 2025-05-08
# Retrieved 167 data for 2025-05-09
# Retrieved 155 data for 2025-05-10
# Retrieved 155 data for 2025-05-11
# Retrieved 155 data for 2025-05-12
# Retrieved 132 data for 2025-05-13
# Retrieved 139 data for 2025-05-14
# Retrieved 169 data for 2025-05-15
# Retrieved 170 data for 2025-05-16
# Retrieved 149 data for 2025-05-17
# Retrieved 148 data for 2025-05-18
# Retrieved 667 data for 2025-02-02
# Retrieved 669 data for 2025-02-03
# Retrieved 634 data for 2025-02-04
# Retrieved 642 data for 2025-02-05
# Retrieved 611 data for 2025-02-06
# Retrieved 622 data for 2025-02-07
# Retrieved 626 data for 2025-02-08
# Retrieved 632 data for 2025-02-09
# Retrieved 639 data for 2025-02-10
# Retrieved 602 data for 2025-02-11
# Retrieved 628 data for 2025-02-12
# Retrieved 652 data for 2025-02-13
# Retrieved 650 data for 2025-02-14
# Retrieved 687 data for 2025-02-15
# Retrieved 670 data for 2025-02-16
# Retrieved 672 data for 2025-02-17
# Retrieved 623 data for 2025-02-18
# Retrieved 652 data for 2025-02-19
# Retrieved 659 data for 2025-02-20
# Retrieved 638 data for 2025-02-21
# Retrieved 687 data for 2025-02-22
# Retrieved 716 data for 2025-02-23
# Retrieved 716 data for 2025-02-24
# Retrieved 676 data for 2025-02-25
# Retrieved 615 data for 2025-02-26
# Retrieved 554 data for 2025-02-27
# Retrieved 519 data for 2025-02-28
# Retrieved 537 data for 2025-03-01
# Retrieved 557 data for 2025-03-02
# Retrieved 557 data for 2025-03-03
# Retrieved 514 data for 2025-03-04
# Retrieved 499 data for 2025-03-05
# Retrieved 492 data for 2025-03-06
# Retrieved 520 data for 2025-03-07
# Retrieved 534 data for 2025-03-08
# Retrieved 509 data for 2025-03-09
# Retrieved 506 data for 2025-03-10
# Retrieved 488 data for 2025-03-11
# Retrieved 456 data for 2025-03-12
# Retrieved 462 data for 2025-03-13
# Retrieved 437 data for 2025-03-14
# Retrieved 434 data for 2025-03-15
# Retrieved 428 data for 2025-03-16
# Retrieved 437 data for 2025-03-17
# Retrieved 429 data for 2025-03-18
# Retrieved 457 data for 2025-03-19
# Retrieved 447 data for 2025-03-20
# Retrieved 440 data for 2025-03-21
# Retrieved 427 data for 2025-03-22
# Retrieved 418 data for 2025-03-23
# Retrieved 415 data for 2025-03-24
# Retrieved 389 data for 2025-03-25
# Retrieved 342 data for 2025-03-26
# Retrieved 348 data for 2025-03-27
# Retrieved 318 data for 2025-03-28
# Retrieved 356 data for 2025-03-29
# Retrieved 363 data for 2025-03-30
# Retrieved 365 data for 2025-03-31
# Retrieved 358 data for 2025-04-01
# Retrieved 310 data for 2025-04-02
# Retrieved 294 data for 2025-04-03
# Retrieved 279 data for 2025-04-04
# Retrieved 289 data for 2025-04-05
# Retrieved 294 data for 2025-04-06
# Retrieved 291 data for 2025-04-07
# Retrieved 278 data for 2025-04-08
# Retrieved 284 data for 2025-04-09
# Retrieved 258 data for 2025-04-10
# Retrieved 247 data for 2025-04-11
# Retrieved 272 data for 2025-04-12
# Retrieved 286 data for 2025-04-13
# Retrieved 280 data for 2025-04-14
# Retrieved 255 data for 2025-04-15
# Retrieved 290 data for 2025-04-16
# Retrieved 299 data for 2025-04-17
# Retrieved 309 data for 2025-04-18
# Retrieved 335 data for 2025-04-19
# Retrieved 345 data for 2025-04-20
# Retrieved 347 data for 2025-04-21
# Retrieved 339 data for 2025-04-22
# Retrieved 297 data for 2025-04-23
# Retrieved 299 data for 2025-04-24
# Retrieved 314 data for 2025-04-25
# Retrieved 337 data for 2025-04-26
# Retrieved 342 data for 2025-04-27
# Retrieved 346 data for 2025-04-28
# Retrieved 333 data for 2025-04-29
# Retrieved 334 data for 2025-04-30
# Retrieved 366 data for 2025-05-01
# Retrieved 417 data for 2025-05-02
# Retrieved 418 data for 2025-05-03
# Retrieved 408 data for 2025-05-04
# Retrieved 416 data for 2025-05-05
# Retrieved 426 data for 2025-05-06
# Retrieved 406 data for 2025-05-07
# Retrieved 414 data for 2025-05-08
# Retrieved 408 data for 2025-05-09
# Retrieved 429 data for 2025-05-10
# Retrieved 441 data for 2025-05-11
# Retrieved 452 data for 2025-05-12
# Retrieved 384 data for 2025-05-13
# Retrieved 362 data for 2025-05-14
# Retrieved 323 data for 2025-05-15
# Retrieved 317 data for 2025-05-16
# Retrieved 317 data for 2025-05-17
# Retrieved 312 data for 2025-05-18
# Retrieved 102 data for 2025-02-02
# Retrieved 102 data for 2025-02-03
# Retrieved 101 data for 2025-02-04
# Retrieved 92 data for 2025-02-05
# Retrieved 78 data for 2025-02-06
# Retrieved 70 data for 2025-02-07
# Retrieved 62 data for 2025-02-08
# Retrieved 63 data for 2025-02-09
# Retrieved 65 data for 2025-02-10
# Retrieved 73 data for 2025-02-11
# Retrieved 75 data for 2025-02-12
# Retrieved 72 data for 2025-02-13
# Retrieved 65 data for 2025-02-14
# Retrieved 54 data for 2025-02-15
# Retrieved 52 data for 2025-02-16
# Retrieved 51 data for 2025-02-17
# Retrieved 48 data for 2025-02-18
# Retrieved 53 data for 2025-02-19
# Retrieved 54 data for 2025-02-20
# Retrieved 51 data for 2025-02-21
# Retrieved 57 data for 2025-02-22
# Retrieved 57 data for 2025-02-23
# Retrieved 57 data for 2025-02-24
# Retrieved 72 data for 2025-02-25
# Retrieved 85 data for 2025-02-26
# Retrieved 90 data for 2025-02-27
# Retrieved 100 data for 2025-02-28
# Retrieved 107 data for 2025-03-01
# Retrieved 105 data for 2025-03-02
# Retrieved 105 data for 2025-03-03
# Retrieved 107 data for 2025-03-04
# Retrieved 112 data for 2025-03-05
# Retrieved 106 data for 2025-03-06
# Retrieved 84 data for 2025-03-07
# Retrieved 80 data for 2025-03-08
# Retrieved 78 data for 2025-03-09
# Retrieved 77 data for 2025-03-10
# Retrieved 72 data for 2025-03-11
# Retrieved 76 data for 2025-03-12
# Retrieved 79 data for 2025-03-13
# Retrieved 78 data for 2025-03-14
# Retrieved 84 data for 2025-03-15
# Retrieved 84 data for 2025-03-16
# Retrieved 85 data for 2025-03-17
# Retrieved 87 data for 2025-03-18
# Retrieved 84 data for 2025-03-19
# Retrieved 75 data for 2025-03-20
# Retrieved 63 data for 2025-03-21
# Retrieved 51 data for 2025-03-22
# Retrieved 48 data for 2025-03-23
# Retrieved 46 data for 2025-03-24
# Retrieved 30 data for 2025-03-25
# Retrieved 32 data for 2025-03-26
# Retrieved 36 data for 2025-03-27
# Retrieved 35 data for 2025-03-28
# Retrieved 30 data for 2025-03-29
# Retrieved 30 data for 2025-03-30
# Retrieved 30 data for 2025-03-31
# Retrieved 27 data for 2025-04-01
# Retrieved 29 data for 2025-04-02
# Retrieved 32 data for 2025-04-03
# Retrieved 38 data for 2025-04-04
# Retrieved 27 data for 2025-04-05
# Retrieved 26 data for 2025-04-06
# Retrieved 26 data for 2025-04-07
# Retrieved 24 data for 2025-04-08
# Retrieved 21 data for 2025-04-09
# Retrieved 27 data for 2025-04-10
# Retrieved 24 data for 2025-04-11
# Retrieved 28 data for 2025-04-12
# Retrieved 31 data for 2025-04-13
# Retrieved 32 data for 2025-04-14
# Retrieved 27 data for 2025-04-15
# Retrieved 34 data for 2025-04-16
# Retrieved 40 data for 2025-04-17
# Retrieved 42 data for 2025-04-18
# Retrieved 42 data for 2025-04-19
# Retrieved 40 data for 2025-04-20
# Retrieved 39 data for 2025-04-21
# Retrieved 37 data for 2025-04-22
# Retrieved 33 data for 2025-04-23
# Retrieved 33 data for 2025-04-24
# Retrieved 30 data for 2025-04-25
# Retrieved 24 data for 2025-04-26
# Retrieved 22 data for 2025-04-27
# Retrieved 22 data for 2025-04-28
# Retrieved 20 data for 2025-04-29
# Retrieved 19 data for 2025-04-30
# Retrieved 23 data for 2025-05-01
# Retrieved 36 data for 2025-05-02
# Retrieved 33 data for 2025-05-03
# Retrieved 33 data for 2025-05-04
# Retrieved 33 data for 2025-05-05
# Retrieved 32 data for 2025-05-06
# Retrieved 28 data for 2025-05-07
# Retrieved 25 data for 2025-05-08
# Retrieved 31 data for 2025-05-09
# Retrieved 34 data for 2025-05-10
# Retrieved 33 data for 2025-05-11
# Retrieved 33 data for 2025-05-12
# Retrieved 22 data for 2025-05-13
# Retrieved 24 data for 2025-05-14
# Retrieved 23 data for 2025-05-15
# Retrieved 26 data for 2025-05-16
# Retrieved 25 data for 2025-05-17
# Retrieved 25 data for 2025-05-18
# Retrieved 61 data for 2025-02-02
# Retrieved 61 data for 2025-02-03
# Retrieved 57 data for 2025-02-04
# Retrieved 53 data for 2025-02-05
# Retrieved 51 data for 2025-02-06
# Retrieved 54 data for 2025-02-07
# Retrieved 62 data for 2025-02-08
# Retrieved 62 data for 2025-02-09
# Retrieved 62 data for 2025-02-10
# Retrieved 58 data for 2025-02-11
# Retrieved 63 data for 2025-02-12
# Retrieved 69 data for 2025-02-13
# Retrieved 72 data for 2025-02-14
# Retrieved 73 data for 2025-02-15
# Retrieved 73 data for 2025-02-16
# Retrieved 73 data for 2025-02-17
# Retrieved 79 data for 2025-02-18
# Retrieved 75 data for 2025-02-19
# Retrieved 78 data for 2025-02-20
# Retrieved 87 data for 2025-02-21
# Retrieved 88 data for 2025-02-22
# Retrieved 88 data for 2025-02-23
# Retrieved 88 data for 2025-02-24
# Retrieved 83 data for 2025-02-25
# Retrieved 74 data for 2025-02-26
# Retrieved 84 data for 2025-02-27
# Retrieved 86 data for 2025-02-28
# Retrieved 92 data for 2025-03-01
# Retrieved 94 data for 2025-03-02
# Retrieved 94 data for 2025-03-03
# Retrieved 86 data for 2025-03-04
# Retrieved 88 data for 2025-03-05
# Retrieved 85 data for 2025-03-06
# Retrieved 94 data for 2025-03-07
# Retrieved 96 data for 2025-03-08
# Retrieved 96 data for 2025-03-09
# Retrieved 96 data for 2025-03-10
# Retrieved 92 data for 2025-03-11
# Retrieved 84 data for 2025-03-12
# Retrieved 87 data for 2025-03-13
# Retrieved 104 data for 2025-03-14
# Retrieved 110 data for 2025-03-15
# Retrieved 110 data for 2025-03-16
# Retrieved 110 data for 2025-03-17
# Retrieved 116 data for 2025-03-18
# Retrieved 108 data for 2025-03-19
# Retrieved 120 data for 2025-03-20
# Retrieved 118 data for 2025-03-21
# Retrieved 111 data for 2025-03-22
# Retrieved 107 data for 2025-03-23
# Retrieved 108 data for 2025-03-24
# Retrieved 91 data for 2025-03-25
# Retrieved 91 data for 2025-03-26
# Retrieved 70 data for 2025-03-27
# Retrieved 74 data for 2025-03-28
# Retrieved 72 data for 2025-03-29
# Retrieved 72 data for 2025-03-30
# Retrieved 72 data for 2025-03-31
# Retrieved 69 data for 2025-04-01
# Retrieved 75 data for 2025-04-02
# Retrieved 86 data for 2025-04-03
# Retrieved 87 data for 2025-04-04
# Retrieved 77 data for 2025-04-05
# Retrieved 77 data for 2025-04-06
# Retrieved 77 data for 2025-04-07
# Retrieved 65 data for 2025-04-08
# Retrieved 65 data for 2025-04-09
# Retrieved 59 data for 2025-04-10
# Retrieved 64 data for 2025-04-11
# Retrieved 54 data for 2025-04-12
# Retrieved 53 data for 2025-04-13
# Retrieved 53 data for 2025-04-14
# Retrieved 57 data for 2025-04-15
# Retrieved 69 data for 2025-04-16
# Retrieved 67 data for 2025-04-17
# Retrieved 56 data for 2025-04-18
# Retrieved 75 data for 2025-04-19
# Retrieved 75 data for 2025-04-20
# Retrieved 74 data for 2025-04-21
# Retrieved 52 data for 2025-04-22
# Retrieved 66 data for 2025-04-23
# Retrieved 73 data for 2025-04-24
# Retrieved 67 data for 2025-04-25
# Retrieved 64 data for 2025-04-26
# Retrieved 67 data for 2025-04-27
# Retrieved 67 data for 2025-04-28
# Retrieved 54 data for 2025-04-29
# Retrieved 44 data for 2025-04-30
# Retrieved 34 data for 2025-05-01
# Retrieved 32 data for 2025-05-02
# Retrieved 29 data for 2025-05-03
# Retrieved 29 data for 2025-05-04
# Retrieved 29 data for 2025-05-05
# Retrieved 27 data for 2025-05-06
# Retrieved 37 data for 2025-05-07
# Retrieved 41 data for 2025-05-08
# Retrieved 44 data for 2025-05-09
# Retrieved 52 data for 2025-05-10
# Retrieved 54 data for 2025-05-11
# Retrieved 54 data for 2025-05-12
# Retrieved 44 data for 2025-05-13
# Retrieved 42 data for 2025-05-14
# Retrieved 46 data for 2025-05-15
# Retrieved 31 data for 2025-05-16
# Retrieved 23 data for 2025-05-17
# Retrieved 23 data for 2025-05-18
# C:\Users\David\AppData\Local\Temp\ipykernel_24188\120158157.py:59: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_train = pd.concat(dfs, ignore_index=True)
# Retrieved 21 data for 2025-05-19 00:00:00
# Retrieved 23 data for 2025-05-20 00:00:00
# Retrieved 23 data for 2025-05-21 00:00:00
# Retrieved 37 data for 2025-05-22 00:00:00
# Retrieved 23 data for 2025-05-23 00:00:00
# Retrieved 16 data for 2025-05-19 00:00:00
# Retrieved 8 data for 2025-05-20 00:00:00
# Retrieved 6 data for 2025-05-21 00:00:00
# Retrieved 21 data for 2025-05-22 00:00:00
# Retrieved 9 data for 2025-05-23 00:00:00
# Retrieved 148 data for 2025-05-19 00:00:00
# Retrieved 160 data for 2025-05-20 00:00:00
# Retrieved 169 data for 2025-05-21 00:00:00
# Retrieved 140 data for 2025-05-22 00:00:00
# Retrieved 109 data for 2025-05-23 00:00:00
# Retrieved 316 data for 2025-05-19 00:00:00
# Retrieved 271 data for 2025-05-20 00:00:00
# Retrieved 219 data for 2025-05-21 00:00:00
# Retrieved 190 data for 2025-05-22 00:00:00
# Retrieved 122 data for 2025-05-23 00:00:00
# Retrieved 25 data for 2025-05-19 00:00:00
# Retrieved 19 data for 2025-05-20 00:00:00
# Retrieved 16 data for 2025-05-21 00:00:00
# Retrieved 15 data for 2025-05-22 00:00:00
# Retrieved 8 data for 2025-05-23 00:00:00
# Retrieved 23 data for 2025-05-19 00:00:00
# Retrieved 17 data for 2025-05-20 00:00:00
# Retrieved 18 data for 2025-05-21 00:00:00
# Retrieved 25 data for 2025-05-22 00:00:00
# Retrieved 22 data for 2025-05-23 00:00:00
# ==============================
# Class distribution in training set:
# next_move
# 0    71036
# 1    19234
# Name: count, dtype: int64
#
# Class distribution in test set:
# next_move
# 0    1151
# 1    1068
# Name: count, dtype: int64
# ==============================
# Missing values in training data:
# containerSizeName      177
# freeReturnDate         226
# emptyDay             10057
# pickupFromTime        7331
# pickupToTime          7442
# deliveryFromTime     11962
# deliveryToTime       12047
# dischargedDate       15218
# availableDate         8012
# dtype: int64
#
# Missing values in test data:
# containerSizeName     18
# freeReturnDate         2
# emptyDay             281
# pickupFromTime       113
# pickupToTime         113
# deliveryFromTime     266
# deliveryToTime       271
# dischargedDate       341
# availableDate        177
# dtype: int64
# ==============================
# C:\Users\David\AppData\Local\Temp\ipykernel_24188\120158157.py:67: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_test = pd.concat(dfs, ignore_index=True)
# Best parameters: {'objective': 'multi:softprob', 'eval_metric': 'mlogloss', 'eta': 0.1, 'max_depth': 8, 'num_class': 2, 'random_state': 42, 'subsample': 0.8, 'colsample_bytree': 1.0, 'num_boost_round': 200}
# Best mlogloss: 0.27309233987779746
# Classification Report for pending_return
# c:\ProgramData\anaconda3\envs\aws\Lib\site-packages\xgboost\core.py:158: UserWarning: [12:14:59] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "num_boost_round" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Accuracy: 0.6863452005407842
# Classification Report:
#                precision    recall  f1-score   support
#
#   Do Nothing       0.65      0.86      0.74      1151
#       Return       0.77      0.50      0.60      1068
#
#     accuracy                           0.69      2219
#    macro avg       0.71      0.68      0.67      2219
# weighted avg       0.71      0.69      0.67      2219
# Feature: revenue, Importance: 228.0
# Feature: shipperName, Importance: 187.0
# Feature: distance, Importance: 157.0
# Feature: freeReturnDate, Importance: 153.0
# Feature: emptyDay, Importance: 142.0
# Feature: consigneeName, Importance: 115.0
# Feature: callerName, Importance: 112.0
# Feature: dischargedDate, Importance: 100.0
# Feature: DOW, Importance: 98.0
# Feature: pickupFromTime, Importance: 81.0
# Feature: deliveryFromTime, Importance: 75.0
# Feature: carrier, Importance: 52.0
# Feature: availableDate, Importance: 51.0
# Feature: pickupToTime, Importance: 23.0
# Feature: containerSizeName, Importance: 21.0
# Feature: deliveryToTime, Importance: 16.0
# Recommended Dispatch Plan is Ready!
